# %% [markdown]
# <a href="https://colab.research.google.com/github/dyhla/atom-script/blob/master/Week4_IP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import pandas as pd
import pandas as pd

# Import numpy as np
import numpy as np

# %%
# Let's read the data from the CSV file and create the dataframe to be used
#

company = pd.read_csv('http://bit.ly/autolib_dataset')
company.head()
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue Eug̬ne Oudin̩     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
#
# [5 rows x 25 columns]

# %%
# checking datatypes
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
# Number of columns
company.columns
# Out:
# Index(['Address', 'Cars', 'Bluecar counter', 'Utilib counter',
#        'Utilib 1.4 counter', 'Charge Slots', 'Charging Status', 'City',
#        'Displayed comment', 'ID', 'Kind', 'Geo point', 'Postal code',
#        'Public name', 'Rental status', 'Scheduled at', 'Slots', 'Station type',
#        'Status', 'Subscription status', 'year', 'month', 'day', 'hour',
#        'minute'],
#       dtype='object')

# %%
# determining the number of records in the dataset
company.shape
# Out:
# (5000, 25)

# %%
# checking for duplicates
company.duplicated().any()
# Out:
# False

# %%
# Checking for the null totals
company.isnull().sum().sort_values(ascending=False)
# Out:
# Scheduled at           4953
# Displayed comment      4889
# Address                   0
# Public name               0
# hour                      0
# day                       0
# month                     0
# year                      0
# Subscription status       0
# Status                    0
# Station type              0
# Slots                     0
# Rental status             0
# Postal code               0
# Cars                      0
# Geo point                 0
# Kind                      0
# ID                        0
# City                      0
# Charging Status           0
# Charge Slots              0
# Utilib 1.4 counter        0
# Utilib counter            0
# Bluecar counter           0
# minute                    0
# dtype: int64

# %%
company.nunique()
# Out:
# Address                1104
# Cars                      8
# Bluecar counter           8
# Utilib counter            3
# Utilib 1.4 counter        4
# Charge Slots              3
# Charging Status           3
# City                     88
# Displayed comment        25
# ID                     1105
# Kind                      4
# Geo point              1105
# Postal code             107
# Public name            1105
# Rental status             4
# Scheduled at              8
# Slots                     8
# Station type              3
# Status                    3
# Subscription status       3
# year                      1
# month                     1
# day                       9
# hour                     24
# minute                   60
# dtype: int64

# %%
# To find numerical statistics of the data
company.describe()
# Out:
#               Cars  Bluecar counter  ...         hour       minute
# count  5000.000000      5000.000000  ...  5000.000000  5000.000000
# mean      2.333600         2.333600  ...    11.509200    29.270000
# std       2.035274         2.035274  ...     6.893549    17.231741
# min       0.000000         0.000000  ...     0.000000     0.000000
# 25%       0.000000         0.000000  ...     6.000000    14.000000
# 50%       2.000000         2.000000  ...    11.000000    29.000000
# 75%       4.000000         4.000000  ...    18.000000    44.000000
# max       7.000000         7.000000  ...    23.000000    59.000000
#
# [8 rows x 12 columns]

# %%
# Checking if there's an empty unnamed variable
company.isnull()
# Out:
#       Address   Cars  Bluecar counter  ...    day   hour  minute
# 0       False  False            False  ...  False  False   False
# 1       False  False            False  ...  False  False   False
# 2       False  False            False  ...  False  False   False
# 3       False  False            False  ...  False  False   False
# 4       False  False            False  ...  False  False   False
# ...       ...    ...              ...  ...    ...    ...     ...
# 4995    False  False            False  ...  False  False   False
# 4996    False  False            False  ...  False  False   False
# 4997    False  False            False  ...  False  False   False
# 4998    False  False            False  ...  False  False   False
# 4999    False  False            False  ...  False  False   False
#
# [5000 rows x 25 columns]

# %%
# Checking for null values and there total
company.isnull().sum()
# Out:
# Address                   0
# Cars                      0
# Bluecar counter           0
# Utilib counter            0
# Utilib 1.4 counter        0
# Charge Slots              0
# Charging Status           0
# City                      0
# Displayed comment      4889
# ID                        0
# Kind                      0
# Geo point                 0
# Postal code               0
# Public name               0
# Rental status             0
# Scheduled at           4953
# Slots                     0
# Station type              0
# Status                    0
# Subscription status       0
# year                      0
# month                     0
# day                       0
# hour                      0
# minute                    0
# dtype: int64

# %%
company.head(20)
# Out:
#                                Address  Cars  ...  hour  minute
# 0                  2 Avenue de Suffren     0  ...    11      43
# 1            145 Rue Raymond Losserand     6  ...     7      24
# 2     2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3               51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4   6 avenue de la Porte de Champerret     3  ...    17      23
# 5                 8 Boulevard Voltaire     0  ...     7       2
# 6                       37 rue Leblanc     0  ...    18      20
# 7          17 Rue des Luaps Prolong̩e     3  ...    22      13
# 8                34 avenue Jean Moulin     1  ...    22      58
# 9         41 boulevard de Rochechouart     6  ...    15       2
# 10                      14 rue Censier     0  ...     4      39
# 11        12 Rue Francis de Pressens̩     1  ...     9      20
# 12  6 avenue de la Porte de Champerret     5  ...    12      22
# 13               34 avenue Jean Moulin     0  ...    21      54
# ...

# %% [markdown]
# **Data cleaning**

# %%
# Renaming a column
#def rename_column(data,var):
  #data = data.rename(columns = {'Displayed comment':'Displayed_comment'}, inplace=True)

#column = "Displayed comment"
#rename_column(company,column)

# %%
# Data cleaning
def drop_col(data,var):
# Convert from object to string
 data['Displayed comment'] = data[data['Displayed comment'].str.replace('/','Displayed comment')]
 # Convert from string to integer
 data['Displayed comment'] = data['Displayed comment'].astype(int)

 return data.head()

#Null_column = ['Displayed comment']
#drop_col(company,Null_column)

# %%
# Declare a variable to hold anew dataframe of a correct column
company_new = company[['Address', 'Cars', 'Bluecar counter', 'Utilib counter',
       'Utilib 1.4 counter', 'Charge Slots', 'Charging Status', 'City',
        'ID', 'Kind', 'Geo point', 'Postal code',
       'Public name', 'Rental status', 'Scheduled at', 'Slots', 'Station type',
       'Status', 'Subscription status', 'year', 'month', 'day', 'hour',
       'minute']]
company_new.head()
company_new = company_new.astype({"Bluecar counter":int})

# %%
#  The most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018

company.loc[(company["Bluecar counter"].between(1,8))&(company['month']==4),['hour']].mode()
# Out:
#    hour
# 0     6

# %%
#  most popular hour for returning cars

company['hour'].mode()
# Out:
# 0    21
# dtype: int64

# %%
# most popular overall station
company["Station type"].mode()
# Out:
# 0    station
# dtype: object

# %%
# What postal code is the most popular for picking up Blue cars?
company.loc[(company["Bluecar counter"].between(1,8)),['Postal code']].mode()
# Out:
#    Postal code
# 0        75015

# %%
# most  overall postal code
company["Postal code"].mode()
# Out:
# 0    75015
# dtype: int64

# %%
#  The most popular hour of the day for picking up a shared electric car (Utilibcar) in the city of Paris over the month of April 2018

company.loc[(company["Utilib counter"].between(1,8))&(company['month']==4),['hour']].mode()
# Out:
#    hour
# 0     5

# %%
#  most popular hour for returning cars

company['hour'].mode()
# Out:
# 0    21
# dtype: int64

# %%
# What postal code is the most popular for picking up Utilib cars?
company.loc[(company["Utilib counter"].between(1,7)),['Postal code']].mode()
# Out:
#    Postal code
# 0        75016
# 1        75017

# %%
#  The most popular hour of the day for picking up a shared electric car (Utilib 1.4 car) in the city of Paris over the month of April 2018

company.loc[(company["Utilib 1.4 counter"].between(1,8))&(company['month']==4),['hour']].mode()
# Out:
#    hour
# 0     3

# %%
# What postal code is the most popular for picking up Utilib 1.4 cars?

company.loc[(company["Utilib 1.4 counter"].between(1,7)),['Postal code']].mode()
# Out:
#    Postal code
# 0        75017

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np
# values = list(company_new.values())
plt.bar(company_new,company_new["Bluecar counter"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-2aae8816c5ae> in <module>()
#       2 import numpy as np
#       3 # values = list(company_new.values())
# ----> 4 plt.bar(company_new,company_new["Bluecar counter"])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...
